# %%
import numpy as np

# %%
from matplotlib import pyplot as plt

# %%
x = np.arange(1,11)

# %%
y = 2 * x +5

# %%
plt.title("中文 demo")
# Out:
# Text(0.5, 1.0, '中文 demo')

# %%
plt.xlabel("x axis caption")
# Out:
# Text(0.5, 0, 'x axis caption')

# %%
plt.ylabel("y axis caption")
# Out:
# Text(0, 0.5, 'y axis caption')

# %%
plt.plot(x,y,"ob")
plt.show()
